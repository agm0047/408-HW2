# %%
import geopandas as gpd
import matplotlib as plt

# %%
states = gpd.read_file(r"C:\Users\amonson\Documents\408-HW2\tl_2025_us_state (1) - Copy")

# %%
populations= gpd.read_file(r"C:\Users\amonson\Documents\408-2\ne_10m_populated_places")

# %%
alabama= states[states['NAME'] == 'Alabama']

# %%
alabama
# Out:
#    REGION DIVISION STATEFP   STATENS GEOID      GEOIDFQ STUSPS     NAME LSAD  \
# 13      3        6      01  01779775    01  0400000US01     AL  Alabama   00
#
#     MTFCC FUNCSTAT         ALAND      AWATER     INTPTLAT      INTPTLON  \
# 13  G4000        A  131186429591  4580729056  +32.7395785  -086.8434469
#
#                                              geometry
# 13  POLYGON ((-85.12733 31.76256, -85.12753 31.762...

# %%
populations_projected = populations.to_crs(alabama.crs)

# %%
alabama_populations = gpd.sjoin(populations_projected, alabama)

# %%
alabama_populations
# Out:
#       SCALERANK  NATSCALE  LABELRANK       FEATURECLA   NAME_left NAMEPAR  \
# 692           8        10        1.0  Populated place      Auburn    None
# 693           8        10        1.0  Populated place    Florence    None
# 1981          7        20        1.0  Populated place      Dothan    None
# 1982          7        20        1.0  Populated place  Tuscaloosa    None
# 1983          7        20        1.0  Populated place     Gadsden    None
# 1984          7        20        1.0  Populated place  Enterprise    None
# 1985          7        20        1.0  Populated place       Selma    None
# 4899          6        30        1.0  Populated place  Birmingham    None
# 4900          6        30        1.0  Populated place      Mobile    None
# 5409          6        30        1.0  Populated place  Huntsville    None
# 6239          4        50        1.0  Admin-1 capital  Montgomery    None
#
#      NAMEALT   NAMEASCII  ADM0CAP CAPIN  ...      GEOIDFQ  STUSPS NAME_right  \
# ...

# %%
alabama_populations.plot()
# Out:
# <Axes: >
